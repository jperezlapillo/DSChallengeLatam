# %% [markdown]
# # Data Scientist Challenge - LATAM Airlines
# - Autor: Joaquín Pérez Lapillo  [_<jperezlapillo@gmail.com>_]
# - Fecha: 28 de Abril de 2022
# __________________________________________________________

# %% [markdown]
# ## Contenido
# 0. [Pre-procesamiento](#seccion0)
# 1. [¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto?](#seccion1)
# 2. [Genera las columnas adicionales y luego expórtelas en un archivo](#seccion2)
# 3. [¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo?
# ¿Qué variables esperarías que más influyeran en predecir atrasos?](#seccion3)
# 4. [Entrena uno o varios modelos (usando el/los algoritmo(s) que prefieras) para estimar la probabilidad de atraso de un vuelo.
# Siéntete libre de generar variables adicionales y/o complementar con variables externas.](#seccion4)
# 5. [Evalúa tu modelo. ¿Qué performance tiene? ¿Qué métricas usaste para evaluar esa performance y por qué? ¿Por qué
# elegiste ese algoritmo en particular? ¿Qué variables son las que más influyen en la predicción? ¿Cómo podrías mejorar la
# performance?](#seccion5)

# %% [markdown]
# ## 0. Pre-procesamiento <a name="seccion0"></a>

# %%
# Importamos el dataset
import pandas as pd
df = pd.read_csv("dataset_SCL.csv", low_memory=False)

# %%
# Chequeamos la estructura general del dataset
df.head()
# Out:
#                Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O Vlo-O  \
# 0  2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00   226
# 1  2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00   226
# 2  2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00   226
# 3  2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00   226
# 4  2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00   226
#
#   Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO              OPERA  \
# 0  SCEL  KMIA   AAL    1    1  2017    Domingo         I  American Airlines
# 1  SCEL  KMIA   AAL    2    1  2017      Lunes         I  American Airlines
# 2  SCEL  KMIA   AAL    3    1  2017     Martes         I  American Airlines
# 3  SCEL  KMIA   AAL    4    1  2017  Miercoles         I  American Airlines
# 4  SCEL  KMIA   AAL    5    1  2017     Jueves         I  American Airlines
#
#    SIGLAORI SIGLADES
# 0  Santiago    Miami
# ...

# %%
# Resumen del tipo de datos por columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68206 entries, 0 to 68205
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha-I    68206 non-null  object
#  1   Vlo-I      68206 non-null  object
#  2   Ori-I      68206 non-null  object
#  3   Des-I      68206 non-null  object
#  4   Emp-I      68206 non-null  object
#  5   Fecha-O    68206 non-null  object
#  6   Vlo-O      68205 non-null  object
#  7   Ori-O      68206 non-null  object
#  8   Des-O      68206 non-null  object
#  9   Emp-O      68206 non-null  object
#  10  DIA        68206 non-null  int64
#  11  MES        68206 non-null  int64
#  12  AÑO        68206 non-null  int64
#  13  DIANOM     68206 non-null  object
#  14  TIPOVUELO  68206 non-null  object
#  15  OPERA      68206 non-null  object
#  16  SIGLAORI   68206 non-null  object
#  17  SIGLADES   68206 non-null  object
# dtypes: int64(3), object(15)
# memory usage: 9.4+ MB

# %%
# Chequeo de missing values
df.isnull().sum()
# Out:
# Fecha-I      0
# Vlo-I        0
# Ori-I        0
# Des-I        0
# Emp-I        0
# Fecha-O      0
# Vlo-O        1
# Ori-O        0
# Des-O        0
# Emp-O        0
# DIA          0
# MES          0
# AÑO          0
# DIANOM       0
# TIPOVUELO    0
# OPERA        0
# SIGLAORI     0
# SIGLADES     0
# dtype: int64

# %%
# Existe un missing de la columna Vlo-O (número de vuelo)
df[df["Vlo-O"].isnull()]
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O Vlo-O  \
# 6068  2017-01-19 11:00:00   200  SCEL  SPJC   LAW  2017-01-19 11:03:00   NaN
#
#      Ori-O Des-O Emp-O  DIA  MES   AÑO  DIANOM TIPOVUELO  \
# 6068  SCEL  SPJC   56R   19    1  2017  Jueves         I
#
#                      OPERA  SIGLAORI SIGLADES
# 6068  Latin American Wings  Santiago     Lima

# %%
# Se imputa con la información de la columna Vlo-I (Programado)
valor_to_imp = df.iloc[df[df["Vlo-O"].isnull()].index]["Vlo-I"].values[0]
df.loc[df[df["Vlo-O"].isnull()].index,"Vlo-O"] = valor_to_imp

# %%
# Chequea imputación
df.isnull().sum()
# Out:
# Fecha-I      0
# Vlo-I        0
# Ori-I        0
# Des-I        0
# Emp-I        0
# Fecha-O      0
# Vlo-O        0
# Ori-O        0
# Des-O        0
# Emp-O        0
# DIA          0
# MES          0
# AÑO          0
# DIANOM       0
# TIPOVUELO    0
# OPERA        0
# SIGLAORI     0
# SIGLADES     0
# dtype: int64

# %%
# Chequeo de duplicados
df.duplicated().sum()
# Out:
# 0

# %%
# Declaramos las columnas de fecha como datetime
df["Fecha-I"] = pd.to_datetime(df["Fecha-I"])
df["Fecha-O"] = pd.to_datetime(df["Fecha-O"])

# %% [markdown]
# ## 1. ¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto? <a name="seccion1"></a>

# %%
# Evaluamos los distintos tipos de origen posibles
df["SIGLAORI"].value_counts()
# Out:
# Santiago    68206
# Name: SIGLAORI, dtype: int64

# %% [markdown]
# - Todos los vuelos salen del aeropuerto de Santiago.

# %%
# Evaluamos los distintos meses en que se operan vuelos
df.groupby(["AÑO", "MES"])["SIGLAORI"].count()
# Out:
# AÑO   MES
# 2017  1      6106
#       2      5561
#       3      5482
#       4      5020
#       5      5240
#       6      4981
#       7      5992
#       8      5744
#       9      5610
#       10     6032
#       11     6080
#       12     6356
# 2018  1         2
# Name: SIGLAORI, dtype: int64

# %% [markdown]
# - Los vuelos fueron operados durante 2017, con excepción de 2 días.

# %%
# Cantidad de vuelos operados por mes
import matplotlib.pyplot as plt
df[df["AÑO"]!=2018].groupby(["AÑO", "MES"])["SIGLAORI"].count().plot(kind="bar")
plt.title("Cantidad de vuelos operados por mes")
plt.show()

# %% [markdown]
# - La mayor cantidad de vuelos se registraron en diciembre y enero, mientras que junio es el mes con menor operación.

# %% [markdown]
# - Llama la atención el alza que se produce de julio, probablemente asociado a vacaciones de invierno, aprovechando la contra-temporada del hemisferio norte y destinos cercanos al ecuador donde siempre hay altas temperaturas.

# %%
# 10 Principales destinos 
df["SIGLADES"].value_counts().head(9).plot(kind="bar")
plt.title("10 Principales destinos")
plt.show()

# %% [markdown]
# - Entre los destinos con mayor cantidad de vuelos operados existen nacionales (Antofagasta, Calama, Puerto Montt, Concepción, Iquique, Temuco) e internacionales (Buenos Aires, Lima, Sao Paulo) que son parte de la región (sudamérica).

# %%
# % acumulado top 10 destinos
perc_vlo = round(df["SIGLADES"].value_counts().head(9).sum() / len(df),2)*100
print("Los 10 primeros destinos acumulan un {}% de los vuelos.".format(perc_vlo))
# Out:
# Los 10 primeros destinos acumulan un 60.0% de los vuelos.

# %%
# Estacionalidad de vuelos durante el año, por destino
df_destinos = df[df["AÑO"]!=2018].groupby(["SIGLADES", "AÑO", "MES"])["SIGLAORI"].count().reset_index()

# %%
# Rename columnas y crea fecha
df_destinos = df_destinos.rename(columns={"SIGLAORI":"COUNT", "AÑO":"year", "MES":"month"})
df_destinos["day"] = 1
df_destinos["FECHA"] = pd.to_datetime(df_destinos[["year", "month", "day"]], format="%Y/%m")

# %%
# Pivot para obtener destinos como columnas
df_destinos_piv = df_destinos.pivot(index="FECHA", columns="SIGLADES", values="COUNT")

# %%
# Eliminamos destinos sin presencia en todos los meses
df_destinos_piv = df_destinos_piv.dropna(axis=1, how="any")

# %%
# Mantenemos solo destinos los 10 con mayor flujo durante el año, con fines de visualización
lista_top10_dest = df["SIGLADES"].value_counts().head(9).index.tolist()

# %%
# Grafico estacionalidad de los top 10 destinos
df_destinos_piv[lista_top10_dest].plot()
plt.title("Estacionalidad de vuelos durante el año, por destino")
plt.show()

# %% [markdown]
# - Sin considerar ciertas excepciones, los principales destinos muestran un perfil estacional similar. Destaca el aumento de Antofagasta y Calama hacia fin de año, probablemente asociado a la estacionalidad de la actividad minera nacional. Sao Paulo muestra un aumento sobre la media en julio, lo que podría explicarse por las vacaciones de invierno.

# %%
# Tasas de variación intermensual por destino
round(df_destinos_piv[lista_top10_dest].pct_change(1)*100, 1).plot()
plt.title("Tasas de variación intermensual por destino")
plt.show()

# %% [markdown]
# - El cálculo de tasas de variación mensuales confirma el comportamiento sobre la media en julio del destino Sao Paulo.

# %%
# Estacionalidad de vuelos durante el año, por "macrodestino" o tipo de vuelo (nacional-internacional)
df_macrodestinos = df[df["AÑO"]!=2018].groupby(["TIPOVUELO", "AÑO", "MES"])["SIGLAORI"].count().reset_index()

# %%
# Rename columnas y crea fecha
df_macrodestinos = df_macrodestinos.rename(columns={"SIGLAORI":"COUNT", "AÑO":"year", "MES":"month"})
df_macrodestinos["day"] = 1
df_macrodestinos["FECHA"] = pd.to_datetime(df_macrodestinos[["year", "month", "day"]], format="%Y/%m")

# %%
# Pivot para obtener destinos como columnas
df_macrodestinos_piv = df_macrodestinos.pivot(index="FECHA", columns="TIPOVUELO", values="COUNT")

# %%
# Grafico estacionalidad de los macrodestinos
df_macrodestinos_piv.plot()
plt.title("Estacionalidad de vuelos durante el año, por tipo")
plt.show()

# %% [markdown]
# - La estacionalidad de las series de vuelos nacionales e internacionales no muestra mayores diferencias, con excepción del perfil que toman hacia diciembre.

# %%
# Tasas de variación intermensual por macrodestinos
round(df_macrodestinos_piv.pct_change(1)*100, 1).plot()
plt.title("Tasa de variación intermensual por tipo de vuelo")
plt.show()

# %% [markdown]
# - En tasas de variación mensual se observa, para diciembre, un menor dinamismo de los vuelos nacionales, mientras el destino internacional muestra una aceleración, todo esto con respecto a la tasa intermensual de noviembre.

# %%
# % de los vuelos por aerolinea operadora
(df["OPERA"].value_counts() / len(df)).plot(kind="bar")
plt.title("Porcentaje de los vuelos por aerolínea")
plt.show()

# %% [markdown]
# - Grupo LATAM da cuenta de un 60% de los vuelos operados, seguido de Sky Airline con un 20%. Las restantes 21 compañías dan cuenta del restante 20%.

# %% [markdown]
# ### Respuesta:
# - Todos los vuelos tienen como **orígen Santiago** (SCEL).
# - Los datos corresponden a **vuelos del año 2017**. Se incluyen 2 vuelos que fueron operados el 1 de enero de 2018, pero en cuanto a vuelos programados estos son todos de 2017.
#     - Llama la atención la **estacionalidad intra-anual de los vuelos**:
#         - Los meses de verano (diciembre, enero) muestran un **incremento de actividad**, en contraste con lo que se observa para meses de invierno como mayo y junio.
#         - Una excepción interesante es lo que ocurre en **julio**, ya que a pesar de ser pleno invierno se observa un alza de actividad, probablemente asociada a las vacaciones de invierno de los colegios. Por parte de los destinos, hay que considerar que en julio el hemisferio norte está en pleno verano (contra-temporada), además de los destinos cercanos al ecuador (caribe, Brasil) que siempre presentan buen tiempo.
#             - Esto se confirma al graficar la **estacionalidad por destino**, para los 10 principales: si bien todos los destinos muestran un alza intermensual entre julio y junio, **Sao Paulo es el destino que muestra la mayor tasa (64%)**. Si bien Sao Paulo no es en sí mismo un destino vacacional, actúa como *hub* de vuelos a otros destinos vacacionales en Brasil (Rio de Janeiro, Florianópolis, Salvador de Bahía).
# - Los 10 destinos con mayor participación en la base, que acumulan un 60% del total de los vuelos, se pueden agrupar en las siguientes categorías de demanda:
#     - **Internacionales:** Buenos aires, Lima, Sao Paulo. Corresponde a vuelos de corto alcance (dentro de sudamérica), destinos populares para viajes de fin de semana largo ("escapadas") y vacaciones.
#     - **Nacionales** relacionados con la **industria minera**: Antofagasta, Calama e Iquique (este último también podría asociarse a vacaciones).
#     - **Nacionales** relacionados con la **industria salmonera**: Puerto Montt.
#     - **Nacionales** relacionados con la **industria forestal**, viajes familiares y universidades: Concepción y Temuco.
# - En términos de la distinción entre **vuelos domésticos e internacionales**, se observa primero que los destinos domésticos tienen una mayor participación en el número de vuelos, con una estacionalidad intra-anual similar a la de los vuelos internacionales. Sin embargo, es interesante que los vuelos nacionales pierden dinamismo hacia diciembre, mientras los internacionales aceleran (en términos de velocidad de expansión intermensual), lo cual es razonable por el inicio de las vacaciones en Chile.
# - Finalmente, en cuanto a las **compañías que operan los vuelos**, se observa que cerca de un 60% son operados por GRUPO LATAM, seguida por SKY AIRLINE con 20%. Las 21 compañías restantes dan cuenta de aprox. 20% de los vuelos.

# %% [markdown]
# ## 2. Genera las columnas adicionales y luego expórtelas en un archivo synthetic_features.csv <a name="seccion2"></a>
#
# - temporada_alta : 1 si Fecha-I está entre 15-Dic y 3-Mar, o 15-Jul y 31-Jul, o 11-Sep y 30-Sep, 0 si no.
# - dif_min : diferencia en minutos entre Fecha-O y Fecha-I .
# - atraso_15 : 1 si dif_min > 15, 0 si no.
# - periodo_dia : mañana (entre 5:00 y 11:59), tarde (entre 12:00 y 18:59) y noche (entre 19:00 y 4:59), en base a
# Fecha-I .

# %%
# temporada alta
import numpy as np
df["temporada_alta"] = np.where((df["Fecha-I"].between("2017-01-01 00:00:00", "2017-03-03 23:59:59") |
                                 df["Fecha-I"].between("2017-12-15 00:00:00", "2017-12-31 23:59:59") |
                                 df["Fecha-I"].between("2017-07-15 00:00:00", "2017-07-31 23:59:59") |
                                 df["Fecha-I"].between("2017-09-11 00:00:00", "2017-09-30 23:59:59") 
                                ),
                                1, 
                                0)

# %%
# dif_min
df["dif_min"] = (df["Fecha-O"] - df["Fecha-I"]).dt.total_seconds() / 60

# %%
# atraso_15
df["atraso_15"] = np.where(df["dif_min"] > 15, 1, 0)

# %%
# periodo_dia
df["periodo_dia"] = np.where(df["Fecha-I"].dt.hour.between(5, 11), "mañana",
                            np.where(df["Fecha-I"].dt.hour.between(12, 18), "tarde", "noche"))

# %%
# Genera archivo synthetic features (engoding=latin1 para mantener caracteres)
synthetic_features = df[["temporada_alta", "dif_min", "atraso_15", "periodo_dia"]]
synthetic_features.to_csv("synthetic_features.csv", encoding="latin1")

# %% [markdown]
# ## 3. ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo? ¿Qué variables esperarías que más influyeran en predecir atrasos? <a name="seccion3"></a>

# %% [markdown]
# - **SUPUESTO:** Solo se considera atraso si la diferencia entre la hora programada y de operación es mayor a 15 minutos.

# %%
# Antes de calcular probabilidades por variables específicas, calculamos la tasa media de atraso
tasa_agg = round(df["atraso_15"].sum() / df["SIGLAORI"].count()*100,1)
print("La tasa media agregada de atraso es {}%.".format(tasa_agg))
# Out:
# La tasa media agregada de atraso es 18.5%.

# %%
# Importamos la función para plotear la tasa de atraso desde utils.py
from utils import get_tasa_atraso

# %%
# Tasa de atraso por: DESTINO
get_tasa_atraso(df, "SIGLADES", tasa_agg)

# %% [markdown]
# - Los vuelos con destinos Cochabamba, Puerto Stanley, Quito, Ushuaia, Sydney tienen una alta probabilidad de atrasarse.
# - Por el contrario, vuelos a Curitiba, Pisco, Washington y Cataratas de Iguazu siempre salen a tiempo.

# %%
# Tasa de atraso por: AEROLINEA
get_tasa_atraso(df, "OPERA", tasa_agg)

# %% [markdown]
# - Los vuelos operados por Plus Ultra, Quantas, Air Canada, LAW y Gol tienen altas probabilidades de atraso.
# - Por el contrario, las aerolineas Aeromexico, United y Delta (entre otras) tienden a cumplir con los horarios planificados.

# %%
# Tasa de atraso por: MES
get_tasa_atraso(df, "MES", tasa_agg)

# %% [markdown]
# - El mes de julio es por lejos el que registra la mayor probabilidad de atraso de vuelos (casi 30%).
# - Por otro lado, marzo y abril muestran tasas de atraso muy por debajo de la media (cerca de 10%).

# %%
# Tasa de atraso por: DIA
get_tasa_atraso(df, "DIANOM", tasa_agg)

# %% [markdown]
# - La distinción por día de la semana parece ser menos atractiva que para las variables anteriores.
# - De todas maneras, se observa que los días viernes, lunes y jueves la tasa de atraso está sobre la media, mientras que días domingo y sábado están por debajo.

# %%
# Tasa de atraso por: TEMPORADA
get_tasa_atraso(df, "temporada_alta", tasa_agg)

# %% [markdown]
# - La distinción por temporada es la que muestra menos potencial como variable explicativa de la probabilidad de atraso, ya que ambas clases están muy cerca del promedio agregado.

# %%
# Tasa de atraso por: TIPO DE VUELO
get_tasa_atraso(df, "TIPOVUELO", tasa_agg)

# %% [markdown]
# - Casi uno de cada 4 vuelos internacionales fue operado con atraso en el período, mientras los vuelos nacionales mostraron un desempeño mejor.

# %% [markdown]
# ### Respuesta:
# - De acuerdo a los gráficos, todas las variables con excepción de TEMPORADA muestran algún grado de **potencial para lograr predecir una probabilidad de atraso de vuelos**.
# - De ellas, las que se esperaría que aportaran en la separabilidad del problema son **DESTINO** y **AEROLINA**. Esto porque muestran mayor **dispersión entre sus posibles estados**, lo que podría ayudar a un algoritmo clasificador.
# - Algunos ejemplos de estados que toman las variables y que son útiles para el objetivo final se resumen en el siguiente cuadro:
#
# VARIABLE     | MAYOR PROB. DE ATRASO      | MENOR PROB. DE ATRASO
# :-------------:|:------------------------:|:-----------------:
# **DESTINO** | COCHABAMBA, PUERTO STANLEY, QUITO | CURITIBA, PISCO, WASHINGTON
# **AEROLINEA** | PLUS ULTRA, QUANTAS, AIR CANADA | AEROMEXICO, DELTA, UNITED
# **MES** | JULIO, DICIEMBRE, OCTUBRE | MARZO, ABRIL
# **DIA** | Viernes, Lunes | Sabado, Domingo
# **TIPO VUELO** | INTERNACIONAL| NACIONAL

# %% [markdown]
# ## 4. Entrena uno o varios modelos (usando el/los algoritmo(s) que prefieras) para estimar la probabilidad de atraso de un vuelo.
# Siéntete libre de generar variables adicionales y/o complementar con variables externas <a name="seccion4"></a>

# %% [markdown]
# - Utilizaremos los features disponibles: **DESTINO, AEROLINEA, MES, DIA, TEMPORADA, TIPO DE VUELO** y **PERIODO DEL DIA.**
# - Adicionalmente, construiremos un nuevo feature llamado **OCUPACION**, que se calculará considerando la cantidad de vuelos planificados en la misma hora de cada vuelo. Este atributo busca incorporar al modelo información sobre **posibles congestiones en el aeropuerto** producto de la operación en paralelo de vuelos, lo que podría incidir en la probabilidad de atraso.
# - Como taget (label) utilizaremos la variable dummy que indica si el vuelo salió atrasado (más de 15 min): **atraso_15**.

# %%
# Construimos el feature OCUPACION
# Creamos columna auxiliar redondeando la fecha planificada
df["Fecha-I_round"] = df["Fecha-I"].dt.round(freq="H")

# %%
# Crea columna conteo de vuelos (OCUPACION) en la hora planificada
count_vuelos = df["Fecha-I_round"].value_counts().reset_index()
count_vuelos = count_vuelos.rename(columns={"Fecha-I_round":"OCUPACION", "index":"Fecha-I_round"})

# %%
# Asigna nueva columna al dataset y elimina la columna auxiliar
df = df.merge(count_vuelos, on="Fecha-I_round")
df = df.drop("Fecha-I_round", axis=1)

# %%
# Análisis sobre la columna OCUPACION
get_tasa_atraso(df, "OCUPACION", tasa_agg)

# %% [markdown]
# - Si bien no es una columna que presente alta varianza o dispersión, del gráfico se intuye que nuevo feature construido, OCUPACION, podría ser de ayuda al problema de clasificación. Se utilizará en forma de *dummy* considerando como punto de corte OCUPACION=12, dado que a partir de ese valor la probabilidad de atraso supera la media agregada (en general):
#     - OCUPACION_baja: cuando OCUPACION < 12.
#     - OCUPACION_alta: cuando OCUPACION >= 12

# %%
# Transforma OCUPACION en variable dummy
df["OCUPACION"] = np.where(df["OCUPACION"] < 12, "baja", "alta")

# %%
# Prepara dataset
feat_name = ["SIGLADES", "OPERA", "MES", "DIANOM", "temporada_alta", "TIPOVUELO", "periodo_dia", "OCUPACION"]
features = df[feat_name]
label = df["atraso_15"]

# %%
# Corrige tipo de datos de MES y DIA
pd.options.mode.chained_assignment = None 
features["MES"] = features["MES"].astype(str)

# %%
# Se elimina "temporada_alta" del listado de features, pues no se transformará en dummy (ya lo es)
feat_name.remove("temporada_alta")

# %%
# Transformamos variables categóricas en dummies
dummies = pd.get_dummies(features[feat_name], prefix=feat_name)
features_dum = pd.concat([features,dummies], axis=1)
features_dum = features_dum.drop(feat_name, 1)
features_dum.shape
# Out:
# (68206, 112)

# %%
# Train test split: 80% de los datos para entrenamiento, 20% para testeo
from sklearn.model_selection import train_test_split

# Parámetros
test_size = 0.2
random_seed = 42

# Split
train_features, test_features = train_test_split(features_dum, test_size=test_size, random_state=random_seed)
train_label, test_label = train_test_split(label, test_size=test_size, random_state=random_seed)

# %%
# Chequea balanceo de clases en el training set
train_label.value_counts() / len(train_label)
# Out:
# 0    0.81332
# 1    0.18668
# Name: atraso_15, dtype: float64

# %% [markdown]
# Estamos en presencia de un problema de **clasificación desbalanceada**, ya que solo un 18.4% de los vuelos salen con más de 15 minutos de atraso.
#
# - Utilizaremos **SMOTE** (Synthetic Minority Over-sampling Technique, Chawla et al 2002) para aumentar de forma sintética la presencia de la clase minoritaria (atraso=1) en el training set. Según pruebas experimentales, realizando este paso se logra aumentar la performance en aprox. 5%.
#
#
# Luego, será necesario utilizar métricas que permitan **corregir el desbalance**:
# - Se elige utilizar la función **balanced_accuracy_score** de Sklearn, que entrega el promedio del Recall de cada clase
# - Recall es equivalente a true positive rate. Luego, el balanced accuracy calcula el promedio del porcentaje de los verdaderos atrasos que son correctamente clasificados y el porcentaje de los verdaderos vuelos a tiempo que son correctamente clasificados.

# %%
# Balanceo del training set: SMOTE
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
train_features_bal, train_label_bal = sm.fit_resample(train_features, train_label)

# %% [markdown]
# ### Machine learning:
# - Se entrenan 4 tipos de algoritmos: Logistic Regression, Random Forest, Naive Bayes y Multilayer Perceptron.
# - Todos estos escogidos por su reconocida capacidad para resolver problemas de clasificación supervisada.
# - Previo a su entrenamiento, se realiza una breve búsqueda para obtener los mejores hiperparámetros para cada algoritmo.
#     - Por motivos de reducir el tiempo de cómputo, no se realiza cross-validation (k=1 en este caso).

# %%
# Importamos función que realiza grid search y obtiene resultados para el mejor modelo desde utils.py
from utils import get_best_params_results

# %%
# Para ignorar warning messages
import warnings
warnings.filterwarnings('ignore')

# Para mantener track del tiempo de computo
import time

# %% [markdown]
# #### 1. Logistic regression

# %%
# Aplica grid search: LR
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
param_grid = {"solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]}

start = time.time()

lr_classifier, lr_accuracy = get_best_params_results(model=model, 
                                                     param_grid=param_grid,
                                                     train_feat=train_features_bal,
                                                     train_label=train_label_bal,
                                                     test_feat=test_features,
                                                     test_label=test_label)

lr_elapsed_time = time.time() - start
print("Tiempo total (LR): {} segundos.".format(round(lr_elapsed_time)))
# Out:
# Tiempo total (LR): 65 segundos.

# %% [markdown]
# #### 2. Random forest

# %%
# Aplica grid search: RF
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=1)
param_grid = {'n_estimators': [100, 300],
              'max_depth' : [50, 100],
              'criterion' : ['gini', 'entropy']}

start = time.time()
rf_classifier, rf_accuracy = get_best_params_results(model=model, 
                                                     param_grid=param_grid,
                                                     train_feat=train_features_bal,
                                                     train_label=train_label_bal,
                                                     test_feat=test_features,
                                                     test_label=test_label)

rf_elapsed_time = time.time() - start
print("Tiempo total (RF): {} segundos.".format(round(rf_elapsed_time)))
# Out:
# Tiempo total (RF): 602 segundos.

# %% [markdown]
# #### 3. Naive Bayes

# %%
# Naive Bayes: probamos 3 Kernels disponibles por separado
# 1. Multinomial
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
param_grid = {"alpha": [0.1, 1, 10]}

start = time.time()
nbm_classifier, nbm_accuracy = get_best_params_results(model=model, 
                                                       param_grid=param_grid,
                                                       train_feat=train_features_bal,
                                                       train_label=train_label_bal,
                                                       test_feat=test_features,
                                                       test_label=test_label)

nbm_elapsed_time = time.time() - start
print("Tiempo total (NB_M): {} segundos.".format(round(nbm_elapsed_time)))
# Out:
# Tiempo total (NB_M): 1 segundos.

# %%
# 2. Gaussian
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
param_grid = {"var_smoothing": [1e-11, 1e-9, 1e-7]}

start = time.time()
nbg_classifier, nbg_accuracy = get_best_params_results(model=model, 
                                                       param_grid=param_grid,
                                                       train_feat=train_features_bal,
                                                       train_label=train_label_bal,
                                                       test_feat=test_features,
                                                       test_label=test_label)

nbg_elapsed_time = time.time() - start
print("Tiempo total (NB_G): {} segundos.".format(round(nbg_elapsed_time)))
# Out:
# Tiempo total (NB_G): 2 segundos.

# %%
# 3. Bernoulli
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
param_grid = {"alpha": [10, 100, 1000]}

start = time.time()
nbb_classifier, nbb_accuracy = get_best_params_results(model=model, 
                                                       param_grid=param_grid,
                                                       train_feat=train_features_bal,
                                                       train_label=train_label_bal,
                                                       test_feat=test_features,
                                                       test_label=test_label)

nbb_elapsed_time = time.time() - start
print("Tiempo total (NB_B): {} segundos.".format(round(nbb_elapsed_time)))
# Out:
# Tiempo total (NB_B): 2 segundos.

# %% [markdown]
# #### 4. Multilayer perceptron

# %%
# Aplica grid search: MLP, Adam optimizer, Early Stopping
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(random_state=1, solver='adam', max_iter=100,
                      verbose=False, early_stopping=True)
param_grid = {'hidden_layer_sizes': [(50,), (100, 100), (200, 200)]}

start = time.time()
mlp_classifier, mlp_accuracy = get_best_params_results(model=model, 
                                                       param_grid=param_grid,
                                                       train_feat=train_features_bal,
                                                       train_label=train_label_bal,
                                                       test_feat=test_features,
                                                       test_label=test_label)

mlp_elapsed_time = time.time() - start
print("Tiempo total (MLP): {} segundos.".format(round(mlp_elapsed_time)))
# Out:
# Tiempo total (MLP): 651 segundos.

# %% [markdown]
# ## 5. Evalúa tu modelo. ¿Qué performance tiene? ¿Qué métricas usaste para evaluar esa performance y por qué? ¿Por qué elegiste ese algoritmo en particular? ¿Qué variables son las que más influyen en la predicción? ¿Cómo podrías mejorar la performance? <a name="seccion5"></a>

# %%
# Visualización del accuracy balanceado por modelo
models = ['Logistic Regression', 
          'Random Forest', 
          'Naive Bayes (Multinomial)',
          'Naive Bayes (Gaussian)',
          'Naive Bayes (Bernoulli)',
          'Multilayer Perceptron']

accuracy = np.array([lr_accuracy, 
                     rf_accuracy, 
                     nbm_accuracy, 
                     nbg_accuracy, 
                     nbb_accuracy, 
                     mlp_accuracy])

colors = ['#636EFA', 
          '#EF553B', 
          '#00CC96', 
          '#AB63FA', 
          '#FFA15A', 
          '#19D3F3']

accuracy = accuracy*100
accuracy_serie = pd.Series(accuracy, index=models).sort_values()
accuracy_serie.plot.barh(color=colors, ec='black')
plt.title('ML algorithms: balanced accuracy score')
plt.xlim(40,65)
plt.xlabel('% of balanced accuracy')
plt.show()

# %%
# Elige mejor modelo
best_model = accuracy_serie.index[-1]
best_metric = round(accuracy_serie[-1],1)
print("Se selecciona el modelo {}, que alcanza un {}% de balanced accuracy.".format(best_model,best_metric))
# Out:
# Se selecciona el modelo Naive Bayes (Multinomial), que alcanza un 62.0% de balanced accuracy.

# %%
# Importamos función para plotear matriz de confusión desde utils.py
from utils import plot_matrix

# %%
# Plot conf matrix
from sklearn.metrics import confusion_matrix
classes = ['A tiempo (0)', 'Atrasado (1)']
title = "Matriz de confusión: Naive Bayes Multinomial"
cm = confusion_matrix(test_label, nbm_classifier.predict(test_features))
plot_matrix(cm, classes, title)

# %%
# RF feature importance
rf_importance = rf_classifier.best_estimator_.feature_importances_
rf_importance = pd.Series(rf_importance, index=train_features.columns).sort_values()[:20]
plt.figure(figsize=(8,6))
rf_importance.plot.barh(color='m')
plt.title('Random forest: feature importance')
plt.show()

# %% [markdown]
# ### Respuesta:
#
# - De los 4 modelos entrenados, el de mayor performance resulta ser **Naive Bayes** (Multinomial, alpha=1.0), alcanzando un accuracy balanceado de **62.5%**.
# - Se utilizó **accuracy balanceado** como medida de performance, pues estamos frente a un problema de clasificación binaria desbalanceado, lo que hace necesario utilizar el promedio del Recall (true positive rate) de ambas clases (0,1).
# - Adicionalmente, los modelos pueden ser evaluados en términos del **tiempo de cómputo** necesario para realizar el entrenamiento y predicción. En este ámbito, Naive Bayes destaca como el modelo de mayor eficiencia pues toma **2 segundos** en realizar ambas tareas, comparado con 13 de Logistic Regression, 75 de Random Forest y 217 de Multilayer Perceptron (tiempo promedio por modelo).
# - Naive Bayes es un **modelo probabilístico** de clasificación supervisada que se basa en un enfoque de **aprendizaje Bayesiano**. El algoritmo intenta obtener la probabilidad a posteriori de que la variable objetivo _y_ de una observación pertenezca a una cierta clase _c<sub>i</sub>_, dado el set de atributos _X_ disponible: P(y=c<sub>i</sub>| X). Para lograrlo, el modelo se entrena utilizando la información disponible en el set de entrenamiento (_likelihood_): la probabilidad de observar los atributos, dados los valores que toman las clases (P(X|y=c<sub>i</sub>)). La predicción es determinada según la clase más probable de ser observada utilizando un operador _argmax_.
# - La elección de este modelo se basó en su reconocida **eficacia en la resolución de problemas supervisados de clasificación**, lo cual lo hace uno de los algoritmos más utilizados en aplicaciones asemejables al problema en cuestión.
# - Para evaluar las variables de mayor influencia en la predicción se pueden utilizar los resultados que entrega **Random Forest** sobre la capacidad que tienen estas para reducir la entropía del set de datos. De acuerdo a los resultados del modelo, los estados de las variables de mayor influencia en los atrasos se mencionan a continuación, confirmando en parte lo expuesto en la etapa de análisis exploratorio de las variables (pregunta 3):
#     - **DESTINOS: Toronto, Puerto Natales, Punta Cana, Neuquén, Tucumán, Orlando, Melbourne, San Juan.**
#     - **AEROLINEAS: Plus Ultra, Austral.**
# - La performance del modelo podría mejorarse incorporando más features que permitan una **mejor separabilidad de las clases**. Posiblemente, datos relacionados con:
#     - El nivel de **ocupación del vuelo**, calculado como el número de pasajeros sobre la capacidad del avión. Vuelos con 100% de ocupación (o incluso sobrevendidos) potencialmente tienen una mayor probabilidad de atrasarse, en comparación a vuelos con baja ocupación.
#     - Las **condiciones climáticas** en el aeropuerto en la hora de salida del vuelo, especialmente información sobre la **velocidad y dirección del viento**, presencia de frentes de mal tiempo, etc.
#     - Información sobre el nivel de **utilización del espacio aéreo** en la hora planificada del vuelo, incluyendo las **llegadas al aeropuerto SCL** y la operación de **vuelos de carga**.
#     - Cantidad de **personal** que participa del proceso de embarque de un vuelo, por categoría:
#         - Aerolíneas operadoras: procesos de check-in, embarque
#         - Empresas externas: manejo de equipajes, carga de combustible
#         - AVSEC-DGAC: chequeo de seguridad
#         - PDI: control de migraciones
